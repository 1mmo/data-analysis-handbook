# %% [markdown]
# <br>
# <br>
# <br>
# <font size=6>Лекция. Введение в нейронные сети</font><br>
# <br>
# Полносвязная нейронная сеть
# <br>
# <br>
#
# - Оптимизация функции потерь
#
# <br>

# %% [markdown]
# <br>
# <font size=4><center>Для задачи <b>классификации</b> используем LogLoss<br></center></font>
# <br>
#
# ![image.png](attachment:image.png)
#
# <br><br>
# <br>
# <font size=4><center>В случае задачи <b>регрессии</b> можно оптимизировать и другие функции потерь.<br>
#     Например, <b>Mean Squared Error.</b><br></center></font>
# <br><br>

# %% [markdown]
# <br>
# <font size=4><center>Оптимизация весов будет происходить с помощью <b>Стохастического градиентного спуска.</b><br></center></font>
# <br>
# <br>
#
# ![image.png](attachment:image.png)
#
# <br>
# <br>
# <font size=4><center>Проблема заключается в том, что вычислить производную от функции потерь по всем весам нейронной сети довольно сложная задача.<br>
#     Для её решения как раз и используется алгоритм backpropagation</center></font>
# <br>
# <br>

# %% [markdown]
# <br>
#
# ![image.png](attachment:image.png)
#
# <br>
